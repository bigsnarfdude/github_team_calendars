# %%
#! /usr/bin/env python
'''
github_team_calendar.py
Python program to scrape friends github to build team calendar for github
'''

import requests
import pandas

def line_draw_target(target):
    my_text=""
    r = requests.get('https://github.com/users/%s/contributions_calendar_data' %target)
    for char in r.text:
        if "[" in char:
            pass
        elif "]" in char:
            pass
        else:
            my_text += char
    the_list = my_text.split(',')
    a=[]
    b=[]
    for line in the_list:
        if len(line)>3:
            a.append(line)
        else:
            b.append(line)
    ts = pandas.Series(b, index=a)
    plt.plot(ts)

# %%
target = "myf"
line_draw_target(target)

# %%
target = "coreylynch"
line_draw_target(target)

# %%
target = "bigsnarfdude"
line_draw_target(target)

# %%
target = "blake41"
line_draw_target(target)

# %%
target = "darius"
line_draw_target(target)

# %%
target = "uctpphd"
line_draw_target(target)

# %%
target = "holgersindbaek"
line_draw_target(target)

# %%
target = "angusb"
line_draw_target(target)

# %%
target = "Dwaynekj"
line_draw_target(target)

# %%
target = "rubychilds"
line_draw_target(target)

# %%
target = "raysohn"
line_draw_target(target)

# %%
target = "Dwaynekj"
line_draw_target(target)

# %%
target = "doda"
line_draw_target(target)
